# %% [markdown]
# ## Segmenting ML researchers based on publications

# %% [markdown]
# My goal is to estimate at a high level the number of top senior ML researchers currently active in the field. My methodology is as follows:
#
# 1. Generate a list of authors who published at one of the top 3 ML conferences in 2020, as measured by h5-index (NeurIPS, ICLR, ICML), by scraping data from conference websites
# 2. Using an API interface to Google Scholar, obtain the publication history of each of these authors
# 3. Determine the number of authors from this group who meet a given thresholds, e.g. > 5 papers published in the last 5 years

# %% [markdown]
# ### (1) Generate initial author list from conference data (2020)

# %%
# icml
from src.icml import read_icml_papers

icml_data = read_icml_papers(filename="./data/icml_2020_papers.txt")
icml_authors = icml_data[3]  # dict linking authors to affiliations

# %%
# neurips
from src.neurips import read_neurips_papers

neurips_data = read_neurips_papers(filename="./data/neurips_2020_accepted.txt")
neurips_authors = neurips_data[3]  # dict linking authors to affiliations

# %%
# iclr
from src.iclr import read_iclr_papers

iclr_data = read_iclr_papers()
icrl_authors = list(
    set(
        [item for sublist in iclr_data.authors.to_list() for item in sublist]
    )
)  # list of authors

# %%
print(f"Total number of authors from ICML: {len(icml_authors)}")
print(f"Total number of authors from NeurIPS: {len(neurips_authors)}")
print(f"Total number of authors from ICRL: {len(icrl_authors)}")
# Out:
# Total number of authors from ICML: 3422
# Total number of authors from NeurIPS: 5926
# Total number of authors from ICRL: 6872

# %%
# combine
import pandas as pd
    
all_authors = {
    **{a: "" for a in icrl_authors},
    **icml_authors,
    **neurips_authors,
}


author_df = pd.DataFrame({
    "author_name": list(all_authors.keys()),
    "affiliations": list(all_authors.values())
})

# %%
print(f"Total number of authors: {len(author_df)}")
author_df.head(10)
# Out:
# Total number of authors: 12948
#      author_name                                    affiliations
# 0     Ryan Lowe*
# 1     Hanshu YAN
# 2    Dylan Shell                          [Texas A&M University]
# 3  Amarjot Singh
# 4    Piotr Indyk                                           [MIT]
# 5    Amin Ghiasi
# 6     Keizo Kato                     [Fujitsu Laboratories Ltd.]
# 7    Yanzhi Wang
# 8     Nenghai Yu  [University of Science, University of Science]
# 9  Andrew Willis

# %% [markdown]
# ### (2) Get publication history for each author from Google Scholar

# %%
from scholarly import scholarly
from tqdm import tqdm

def get_author_history(author_name):
    print(author_name)
    search_query = scholarly.search_author(author_name)
    try:
        author_history = scholarly.fill(next(search_query))
    except StopIteration as e:
        print("Couldn't find history")
        author_history = {}
    return author_history

test_df = author_df.head(100)

test_df["full_author_history"] = test_df.apply(
#     lambda a: get_author_history(f"{a.author_name} ({a.affiliations[0] if len(a.affiliations) > 0 else ''})"),
    lambda a: get_author_history(a.author_name),
    axis=1
)

# # Print the titles of the author's publications
# print([pub['bib']['title'] for pub in author['publications']])

# # Take a closer look at the first publication
# pub = scholarly.fill(author['publications'][0])
# print(pub)

# # Which papers cited that publication?
# print([citation['bib']['title'] for citation in scholarly.citedby(pub)])
# Out:
# Ryan Lowe*
# Couldn't find history
# Hanshu YAN
# Dylan Shell
# Amarjot Singh
# Piotr Indyk

# %%
# author["citedby5y"]
# author["hindex"]
# author["hindex5y"]
author["publications"]
# Out:
# [{'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'Densepose: Dense human pose estimation in the wild',
#    'pub_year': '2018'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:R3hNpaxXUhUC',
#   'num_citations': 440},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'Houdini: Fooling deep structured visual and speech recognition models with adversarial examples',
#    'pub_year': '2017'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:hFOr9nPyWt4C',
#   'num_citations': 230},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'ModDrop: adaptive multi-modal gesture recognition',
#    'pub_year': '2014'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:YsMSGLbcyi4C',
#   'num_citations': 218},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'Multi-scale deep learning for gesture detection and localization',
#    'pub_year': '2014'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:Y0pCki6q_DkC',
#   'num_citations': 209},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'Predicting Deeper into the Future of Semantic Segmentation',
#    'pub_year': '2017'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:dhFuZR0502QC',
#   'num_citations': 154},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'Learning human identity from motion patterns',
#    'pub_year': '2016'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:Zph67rFs4hoC',
#   'num_citations': 130},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'Dense Pose Transfer', 'pub_year': '2018'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:_Qo2XoVZTnwC',
#   'num_citations': 89},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'Object Level Visual Reasoning in Videos',
#    'pub_year': '2018'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:e5wmG9Sq2KIC',
#   'num_citations': 62},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'A Multi-scale Approach to Gesture Detection and Recognition',
#    'pub_year': '2013'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:zYLM7Y9cAGgC',
#   'num_citations': 61},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'Hand pose estimation through weakly-supervised learning of a rich intermediate representation',
#    'pub_year': '2017'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:ULOm3_A8WrAC',
#   'num_citations': 46},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'Multi-task, multi-domain learning: application to semantic segmentation and pose regression',
#    'pub_year': '2017'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:7PzlFSSx8tAC',
#   'num_citations': 43},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'C3DPO: Canonical 3D Pose Networks for Non-Rigid Structure From Motion',
#    'pub_year': '2019'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:TFP_iSt0sucC',
#   'num_citations': 32},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'Hand segmentation with structured convolutional learning',
#    'pub_year': '2014'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:8k81kl-MbHgC',
#   'num_citations': 32},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'Lighting estimation in indoor environments from low-quality images',
#    'pub_year': '2012'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:u5HHmVD_uO8C',
#   'num_citations': 21},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'Modout: learning to fuse face and gesture modalities with stochastic regularization',
#    'pub_year': '2017'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:9ZlFYXVOiuMC',
#   'num_citations': 16},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': '21/2 D Scene Reconstruction of Indoor Scenes from Single RGB-D Images',
#    'pub_year': '2013'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:2osOgNQ5qMEC',
#   'num_citations': 14},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'Edge-based method for sharp region extraction from low depth of field images',
#    'pub_year': '2012'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:9yKSN-GCB0IC',
#   'num_citations': 14},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'Deep learning for human motion analysis',
#    'pub_year': '2016'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:4DMP91E08xMC',
#   'num_citations': 11},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'Slim DensePose: Thrifty Learning From Sparse Annotations and Motion Cues',
#    'pub_year': '2019'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:iH-uZ7U-co4C',
#   'num_citations': 10},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'Cophy: Counterfactual learning of physical dynamics',
#    'pub_year': '2019'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:isC4tDSrTZIC',
#   'num_citations': 9},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'Modout: Learning to Fuse Modalities via Stochastic Regularization',
#    'pub_year': '2016'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:Wp0gIr-vW9MC',
#   'num_citations': 8},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'Exemplar Fine-Tuning for 3D Human Pose Fitting Towards In-the-Wild 3D Human Pose Estimation',
#    'pub_year': '2020'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:M3NEmzRMIkIC',
#   'num_citations': 7},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'Квазираспределенная измерительная система на основе брэгговских датчиков механических напряжений с повышенной частотой опроса',
#    'pub_year': '2008'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:4TOpqqG69KYC',
#   'num_citations': 7},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'Transferring dense pose to proximal animal classes',
#    'pub_year': '2020'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:maZDTaKrznsC',
#   'num_citations': 6},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'Quasi-distributed measuring system based on fiber Bragg sensors of mechanical stress to the increased frequency of polling',
#    'pub_year': '2008'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:M3ejUd6NZC8C',
#   'num_citations': 6},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'HRI in an ecological dynamic experiment: the GEE corpus based approach for the Emox robot',
#    'pub_year': '2015'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:kNdYIx-mwKoC',
#   'num_citations': 5},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'Mass Displacement Networks', 'pub_year': '2018'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:IWHjjKOFINEC',
#   'num_citations': 4},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'Quasi-distributed measuring system based on Bragg sensors of mechanical stress with increased sample rate',
#    'pub_year': '2010'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:d1gkVwhDpl0C',
#   'num_citations': 4},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'Многоканальная квазираспределенная информационно-измерительная система на основе наноразмерных волоконно-оптических структур датчиков механических напряжений',
#    'pub_year': '2008'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:qxL8FJ1GzNcC',
#   'num_citations': 4},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'Correlated Uncertainty for Learning DenseCorrespondences from Noisy Labels',
#    'pub_year': '2019'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:bEWYMUwI8FkC',
#   'num_citations': 3},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'Metrological support of measurements of the parameters of wavelength dense multiplexing FOTS',
#    'pub_year': '2009'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:u-x6o8ySG0sC',
#   'num_citations': 3},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'Измерительное устройство контроля деформации и температуры на основе наноразмерных волоконно-оптических датчиков',
#    'pub_year': '2008'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:aqlVkmm33-oC',
#   'num_citations': 3},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': '3D scene reconstruction and augmenting using depth sensors',
#    'pub_year': '2012'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:KlAtU1dfN6UC',
#   'num_citations': 2},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'Continuous Surface Embeddings', 'pub_year': '2020'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:blknAaTinKkC',
#   'num_citations': 0},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'CVPR 2018', 'pub_year': '2016'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:r0BpntZqJG4C',
#   'num_citations': 0},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'Collaborators', 'pub_year': '2015'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:j3f4tGmQtD8C',
#   'num_citations': 0},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'Calibration system for fiber Bragg grating strain sensors',
#    'pub_year': '2009'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:3fE2CSJIrl8C',
#   'num_citations': 0},
#  {'container_type': 'Publication',
#   'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#   'bib': {'title': 'Predicting Deeper into the Future of Semantic Segmentation—Supplementary Material—'},
#   'filled': False,
#   'author_pub_id': 'cLPaHcIAAAAJ:qUcmZB5y_30C',
#   'num_citations': 0}]
